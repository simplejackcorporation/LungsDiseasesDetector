# %% [markdown]
# <a href="https://colab.research.google.com/github/simplejackcorporation/LungsDiseasesDetector/blob/main/object_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/LungsDiseasesDetector
# !git clone https://github.com/simplejackcorporation/LungsDiseasesDetector
# Out:
# Cloning into 'LungsDiseasesDetector'...
# remote: Enumerating objects: 261, done.
# remote: Counting objects: 100% (261/261), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 507 (delta 158), reused 233 (delta 139), pack-reused 246
# Receiving objects: 100% (507/507), 67.71 MiB | 36.26 MiB/s, done.
# Resolving deltas: 100% (282/282), done.

# %%
# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 1.9MB 17.8MB/s
# ...

# %%
# !wget https://www.dropbox.com/s/du6q5senjgafc9n/lungs_train_2000.zip
# Out:
# --2021-03-02 22:55:49--  https://www.dropbox.com/s/du6q5senjgafc9n/lungs_train_2000.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/du6q5senjgafc9n/lungs_train_2000.zip [following]
# --2021-03-02 22:55:49--  https://www.dropbox.com/s/raw/du6q5senjgafc9n/lungs_train_2000.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc8b3798db9a13d514415a8d4f3.dl.dropboxusercontent.com/cd/0/inline/BJ_sV9qY_vTTifQeAyfIKzlylHLyjlB85pfJJUwcXOVYb5N2khv3FWWPeL__vZuZ82MS-U6ltbqQ0EhR4e4VXlOQsYg8jiq0cTlwNFwLuN47yVGdi46gc2vdLfYAkhXWwk4/file# [following]
# ...

# %%
import zipfile
with zipfile.ZipFile("/content/lungs_train_2000.zip","r") as zip_ref:
    zip_ref.extractall("lungs_train_2000")

# %%
# !rm /content/lungs_train_2000.zip

# %%
# !python LungsDiseasesDetector/lungs-finder/train.py
# Out:
# 2021-03-02 23:57:10.680469: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From LungsDiseasesDetector/lungs-finder/train.py:16: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2021-03-02 23:57:12.320746: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 23:57:12.321547: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-02 23:57:12.327015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'
